# %% [markdown]
# # RSML Tutorial in Python

# %% [markdown]
# First, we activate matplotlib and qt in the Notebook

# %%
# %matplotlib inline

# %% [markdown]
# Then, we import main modules and function to work with RSML format in Python

# %%
from pprint import pprint
from openalea.core.path import path
from openalea.deploy.shared_data import shared_data
import rsml
from rsml.plot import multiple_plot

# %%
data = shared_data(rsml)
files = data.glob('*.rsml')

# %%
data = shared_data(rsml)
arabido = data/'AR570'
files = arabido.glob('*.rsml')
pprint(files)
# Out:
# [Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_19_18h00_chl110_1_1.rsml'),
#  Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_24_09h00_chl110_1_1.rsml'),
#  Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_20_08h30_chl110_1_1.rsml'),
#  Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_25_09h00_chl110_1_1.rsml'),
#  Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_21_09h00_chl110_1_1.rsml'),
#  Path('/Users/pradal/devlp/git/RSML/share/data/AR570/2012_11_23_09h00_chl110_1_1.rsml')]

# %%
multiple_plot(files, image=False)

# %%
multiple_plot(files, image=True)

# %%
# %run demo_plot_rsml.py
